# %%
# !pip install pysr sympy loguru scikit-learn xgboost pykan==0.1.1 torch -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/99.3 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.3/253.3 kB 10.0 MB/s eta 0:00:00

# %%
# !git clone https://github.com/Dr-Yehia/corrosion-rc-beam-optimizer
# %cd corrosion-rc-beam-optimizer
# !git checkout claude/analyze-corrosion-results-mFrN2
# Out:
# Cloning into 'corrosion-rc-beam-optimizer'...
# remote: Enumerating objects: 1046, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 1046 (delta 47), reused 33 (delta 17), pack-reused 964 (from 2)
# Receiving objects: 100% (1046/1046), 386.06 MiB | 41.33 MiB/s, done.
# Resolving deltas: 100% (435/435), done.
# Updating files: 100% (669/669), done.
# /kaggle/working/corrosion-rc-beam-optimizer
# Branch 'claude/analyze-corrosion-results-mFrN2' set up to track remote branch 'claude/analyze-corrosion-results-mFrN2' from 'origin'.
# Switched to a new branch 'claude/analyze-corrosion-results-mFrN2'

# %%
# !python resultss/pysr_stacking_moead_selector.py
# Out:
# 16:26:04 | INFO     | Loading + preprocessing full dataset ...
# 16:26:04 | INFO     | Loading raw data from: /kaggle/working/corrosion-rc-beam-optimizer/data/Database.csv
# 16:26:04 | INFO     | Raw data loaded (encoding=utf-8-sig) — shape: (804, 60)
# 16:26:04 | INFO     | Column names normalised: ['No.', 'Mass Loss (Tensile bars), ηm (%)', 'Mmax,exp (kNm)', 'Mmax,exp (kNm)']
# 16:26:04 | INFO     | After column fix — shape: (804, 59)
# 16:26:04 | INFO     | Starting data cleaning ...
# 16:26:04 | INFO     | Columns selected: 20 (3 categorical + 15 numeric)
# 16:26:04 | INFO     | Dropped 0 rows with missing target (Mmax,exp (kNm)).
# 16:26:04 | INFO     |   Imputed 'fy Longitudinal Bars (Tensile), (MPa) ' (7 nulls) with median = 374.860
# 16:26:04 | INFO     |   Imputed 'fy,s Stirrup Bars' (119 nulls) with median = 250.000
# 16:26:04 | INFO     |   Imputed 'Mass Loss (Tensile bars), ηm (%)' (13 nulls) with median = 6.980
# ...

# %%
# !python resultss/export_results.py
# Out:
#   + resultss/equations/all_equations.json
#   + resultss/equations/best_equation.latex
#   + resultss/equations/best_equation.txt
#   + resultss/equations/best_equation_stacking.latex
#   + resultss/equations/best_equation_stacking.txt
#   + resultss/figures/fig10_pareto_mmax_performance.png
#   + resultss/figures/fig11_ratio_vs_eta.png
#   + resultss/figures/fig1_predicted_vs_experimental.png
#   + resultss/figures/fig1b_linear_scatter.png
#   + resultss/figures/fig2_test_set_scatter.png
#   + resultss/figures/fig3_ensemble_vs_aci_scatter.png
#   + resultss/figures/fig4_kfold_boxplot.png
#   + resultss/figures/fig5_error_distribution.png
#   + resultss/figures/fig6_model_comparison.png
#   + resultss/figures/fig7_taylor_diagram.png
#   + resultss/figures/fig8_pysr_equation_scatter.png
#   + resultss/figures/fig9_pareto_curve.png
#   + resultss/figures/pysr_stacking_endpoints.png
#   + resultss/figures/pysr_stacking_scatter.png
#   + resultss/figures/shap_beeswarm.png
# ...
